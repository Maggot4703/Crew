# %% [markdown]
# ---
# ---
# # Crew.py
# ---

# %%
#help("modules")

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
help("topics")
# Out:
# Here is a list of available topics.  Enter any topic name to get more help.
#
# ASSERTION           DELETION            LOOPING             SHIFTING
# ASSIGNMENT          DICTIONARIES        MAPPINGMETHODS      SLICINGS
# ATTRIBUTEMETHODS    DICTIONARYLITERALS  MAPPINGS            SPECIALATTRIBUTES
# ATTRIBUTES          DYNAMICFEATURES     METHODS             SPECIALIDENTIFIERS
# AUGMENTEDASSIGNMENT ELLIPSIS            MODULES             SPECIALMETHODS
# BASICMETHODS        EXCEPTIONS          NAMESPACES          STRINGMETHODS
# BINARY              EXECUTION           NONE                STRINGS
# BITWISE             EXPRESSIONS         NUMBERMETHODS       SUBSCRIPTS
# BOOLEAN             FLOAT               NUMBERS             TRACEBACKS
# CALLABLEMETHODS     FORMATTING          OBJECTS             TRUTHVALUE
# CALLS               FRAMEOBJECTS        OPERATORS           TUPLELITERALS
# CLASSES             FRAMES              PACKAGES            TUPLES
# ...

# %%
#help("ASSERTION")
#help("ASSIGNMENT")
#help("ATTRIBUTEMETHODS")
#help("ATTRIBUTES")
#help("AUGMENTEDASSIGNMENT")
#help("BASICMETHODS")
#help("BINARY")
#help("BITWISE")
#help("BOOLEAN")
#help("CALLABLEMETHODS")
#help("CALLS")
#help("CLASSES")
#help("CODEOBJECTS")
#help("COMPARISON")
#help("COMPLEX")
#help("CONDITIONAL")
#help("CONTEXTMANAGERS")
#help("CONVERSIONS")
#help("DEBUGGING")
#help("DELETION")
#help("DICTIONARIES")
#help("DICTIONARYLITERALS")
#help("DYNAMICFEATURES")
#help("ELLIPSIS")
#help("EXCEPTIONS")
#help("EXECUTION")
#help("EXPRESSIONS")
#help("FLOAT")
#help("FORMATTING")
#help("FRAMEOBJECTS")
#help("FRAMES")
#help("FUNCTIONS")
#help("IDENTIFIERS")
#help("IMPORTING")
#help("INTEGER")
#help("LISTLITERALS")
#help("LISTS")
#help("LITERALS")
#help("LOOPING")
#help("MAPPINGMETHODS")
#help("MAPPINGS")
#help("METHODS")
#help("MODULES")
#help("NAMESPACES")
#help("NONE")
#help("NUMBERMETHODS")
#help("NUMBERS")
#help("OBJECTS")
#help("OPERATORS")
#help("PACKAGES")
#help("POWER")
#help("PRECEDENCE")
#help("PRIVATENAMES")
#help("RETURNING")
#help("SCOPING")
#help("SEQUENCEMETHODS")
#help("SEQUENCES")
#help("SHIFTING")
#help("SLICINGS")
#help("SPECIALATTRIBUTES")
#help("SPECIALIDENTIFIERS")
#help("SPECIALMETHODS")
#help("STRINGMETHODS")
#help("STRINGS")
#help("SUBSCRIPTS")
#help("TRACEBACKS")
#help("TRUTHVALUE")
#help("TUPLELITERALS")
#help("TUPLES")
#help("TYPEOBJECTS")
#help("TYPES")
#help("UNARY")
#help("UNICODE")
# Out:
# The "assert" statement
# **********************
#
# Assert statements are a convenient way to insert debugging assertions
# into a program:
#
#    assert_stmt ::= "assert" expression ["," expression]
#
# The simple form, "assert expression", is equivalent to
#
#    if __debug__:
#        if not expression: raise AssertionError
#
# The extended form, "assert expression1, expression2", is equivalent to
#
#    if __debug__:
#        if not expression1: raise AssertionError(expression2)
#
# These equivalences assume that "__debug__" and "AssertionError" refer
# to the built-in variables with those names.  In the current
# implementation, the built-in variable "__debug__" is "True" under
# normal circumstances, "False" when optimization is requested (command
# line option "-O").  The current code generator emits no code for an
# assert statement when optimization is requested at compile time.  Note
# that it is unnecessary to include the source code for the expression
# ...

# %% [markdown]
# ---
# Program Dir

# %%
# !pwd
# !echo ""
# !ls
# Out:
# /home/me/BACKUP/PROJECTS/Crew
#
#  a.wav					 mcp_example.py
#  cache.py				 mcp.py
#  cheat--markdown.md			 mcp_service.py
#  COMPLETION_SUMMARY.txt			 output
#  config.json				 output.txt
#  config.py				 output.txt.py
#  CONTRIBUTING.md			 Pipfile
#  crew_app.log				 project_summary.md
#  Crew.code-workspace			 __pycache__
#  crew_database.db			 read_books.txt
#  crew_data.db				'Reading Now'
#  crew_gui.log				 README.md
#  crew.ipynb				 ReadMine_completion_report.py
#  crew.jupyterlab-workspace		 readmine_progress.json
#  crew.md				 ReadMine.py
#  Crew.py				 read_use_file_cli.py
#  crew.txt				 read_use_file_cli_venv.sh
#  data					 read_use_file.log
#  database_manager.py			 read_use_file.py
#  data_manager.py			 read_use_file_venv.sh
#  disk-cleanup.sh			 read_use.sh
#  dummy_bmps				 read_use_venv.sh
#  enhanced_features.py			 refactoring_verification.py
#  enhanced_fetch_docs.py			 requirements-dev.txt
#  error_handler.py			 requirements.txt
# ...

# %% [markdown]
# ---
# Jupyter Lab Magic

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# ---
# functions @ /home/me/Desktop/T5/Spinward Marches/ODT/PY/OpenEmpires-upgraded/xsrc/dbviewer/globals/GlobalMethods.java

# %%
src = "/home/me/Desktop/T5/Spinward Marches/ODT/PY/OpenEmpires-upgraded/xsrc/dbviewer/globals/GlobalMethods.java"
with open(src, "r") as file:
    data = file.read()
    #print(data)

# %% [markdown]
# ---

# %%
# !npm --help
# Out:
# npm <command>
#
# Usage:
#
# npm install        install all the dependencies in your project
# npm install <foo>  add the <foo> dependency to your project
# npm test           run this project's tests
# npm run <foo>      run the script named <foo>
# npm <command> -h   quick help on <command>
# npm -l             display usage info for all commands
# npm help <term>    search for help on <term>
# npm help npm       more involved overview
#
# All commands:
#
#     access, adduser, audit, bugs, cache, ci, completion,
#     config, dedupe, deprecate, diff, dist-tag, docs, doctor,
#     edit, exec, explain, explore, find-dupes, fund, get, help,
#     hook, init, install, install-ci-test, install-test, link,
#     ll, login, logout, ls, org, outdated, owner, pack, ping,
#     pkg, prefix, profile, prune, publish, query, rebuild, repo,
#     restart, root, run-script, search, set, shrinkwrap, star,
#     stars, start, stop, team, test, token, uninstall, unpublish,
# ...

# %%
# !uv --help
# Out:
# /bin/bash: line 1: uv: command not found

# %%
# !pipenv --help
# Out:
# Usage: pipenv [OPTIONS] COMMAND [ARGS]...
#
# Options:
#   --where                         Output project home information.
#   --venv                          Output virtualenv information.
#   --py                            Output Python interpreter information.
#   --envs                          Output Environment Variable options.
#   --rm                            Remove the virtualenv.
#   --bare                          Minimal output.
#   --man                           Display manpage.
#   --support                       Output diagnostic information for use in
#                                   GitHub issues.
#   --site-packages / --no-site-packages
#                                   Enable site-packages for the virtualenv.
#                                   [env var: PIPENV_SITE_PACKAGES]
#   --python TEXT                   Specify which version of Python virtualenv
#                                   should use.
# ...

# %%
# !jupyter --help
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: bundlerextension dejavu events execute fileid kernel
# kernelspec lab labextension labhub migrate nbclassic nbconvert nbextension
# notebook run server serverextension troubleshoot trust
